# %% [markdown]
# # Cell 1: Import Libraries
# import sys
# sys.path.append('..')  # Add parent directory to path
#
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# import seaborn as sns
# from src.data_preprocessing import *
#
# # Set style
# plt.style.use('seaborn-v0_8')
# sns.set_palette("husl")

# %%
import sys
import os
sys.path.append(os.path.abspath('..'))

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from src.data_preprocessing import (
    load_iris_data,
    load_breast_cancer_data,
    load_wine_data,
    load_california_housing_data,
    split_and_scale_data,
    explore_data
)

plt.style.use('seaborn-v0_8')
sns.set_palette("husl")
print("✅ Imports done")

# %%
print("📊 Loading datasets...")

X_iris, y_iris, features_iris, targets_iris = load_iris_data()
X_cancer, y_cancer, features_cancer, targets_cancer = load_breast_cancer_data()
X_wine, y_wine, features_wine, targets_wine = load_wine_data()
X_housing, y_housing, features_housing = load_california_housing_data()

print("✅ All loaded")

# %%
# Cell 3: Iris Dataset Analysis
print("\n" + "="*60)
print("🌺 IRIS DATASET ANALYSIS")
print("="*60)

# Create DataFrame with all data
df_iris = pd.DataFrame(X_iris, columns=features_iris)
# Add target as a new column
df_iris['target'] = y_iris
df_iris['species_name'] = df_iris['target'].map({0: 'setosa', 1: 'versicolor', 2: 'virginica'})

# Display
display(df_iris.head())
display(df_iris.describe())

print(f"\nMissing values: {df_iris.isnull().sum().sum()}")

# %%
# Cell 5: Explore Breast Cancer Dataset
print("\n" + "="*60)
print("🩺 BREAST CANCER DATASET ANALYSIS")
print("="*60)

df_cancer = pd.DataFrame(X_cancer, columns=features_cancer)
df_cancer['target'] = y_cancer
df_cancer['diagnosis'] = df_cancer['target'].map({0: 'malignant', 1: 'benign'})

display(df_cancer.head())

# Target distribution
print("\nTarget distribution:")
print(df_cancer['diagnosis'].value_counts())

# %%
sns.pairplot(df_iris, hue='species_name', diag_kind='hist')
plt.suptitle('Iris Dataset - Pairplot', y=1.02)
plt.show()

# %%
print("\n" + "="*60)
print("🩺 BREAST CANCER DATASET ANALYSIS")
print("="*60)

# Create DataFrame with features
df_cancer = pd.DataFrame(X_cancer, columns=features_cancer)
# Add target as a new column
df_cancer['target'] = y_cancer
# Create diagnosis column from target
df_cancer['diagnosis'] = df_cancer['target'].map({0: 'malignant', 1: 'benign'})

# Display first few rows
display(df_cancer.head())

print("\nTarget distribution:")
print(df_cancer['diagnosis'].value_counts())

# %%
X_train, X_test, y_train, y_test, scaler = split_and_scale_data(X_iris, y_iris)
print(f"X_train shape: {X_train.shape}")
print(f"X_test shape: {X_test.shape}")

# %%
# Cell 9: Summary
print("\n" + "="*60)
print("✅ DATA EXPLORATION COMPLETE")
print("="*60)
print("\nAll datasets loaded successfully!")
print("\nReady for model implementation.")
